# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('F:/Education/DS_Roadmap/ml/18_PCA/Exercise/heart.csv')
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.shape
# Out:
# (918, 12)

# %%
np.unique(df.ChestPainType)
# Out:
# array(['ASY', 'ATA', 'NAP', 'TA'], dtype=object)

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.isna().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df['zscore_cholestrol'] = (df.Cholesterol-df.Cholesterol.mean())/df.Cholesterol.std()

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease  zscore_cholestrol
# 0              N      0.0       Up             0           0.824621
# 1              N      1.0     Flat             1          -0.171867
# 2              N      0.0       Up             0           0.769768
# 3              Y      1.5     Flat             1           0.138964
# 4              N      0.0       Up             0          -0.034736

# %%
df[df.zscore_cholestrol>3]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 76    32   M           ASY        118          529          0     Normal
# 149   54   M           ASY        130          603          1     Normal
# 616   67   F           NAP        115          564          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease  zscore_cholestrol
# 76     130              N      0.0     Flat             1           3.018723
# 149    125              Y      1.0     Flat             1           3.695238
# 616    160              N      1.6     Flat             0           3.338696

# %%
df.shape
# Out:
# (918, 13)

# %%
df[df.zscore_cholestrol<-3]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease, zscore_cholestrol]
# Index: []

# %%
df[(df.zscore_cholestrol<-3) | (df.zscore_cholestrol>3)]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 76    32   M           ASY        118          529          0     Normal
# 149   54   M           ASY        130          603          1     Normal
# 616   67   F           NAP        115          564          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease  zscore_cholestrol
# 76     130              N      0.0     Flat             1           3.018723
# 149    125              Y      1.0     Flat             1           3.695238
# 616    160              N      1.6     Flat             0           3.338696

# %%
df1 = df[(df.zscore_cholestrol>-3) & (df.zscore_cholestrol<3)]
df1.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease  zscore_cholestrol
# 0              N      0.0       Up             0           0.824621
# 1              N      1.0     Flat             1          -0.171867
# 2              N      0.0       Up             0           0.769768
# 3              Y      1.5     Flat             1           0.138964
# 4              N      0.0       Up             0          -0.034736

# %%
df1.shape
# Out:
# (915, 13)

# %%
df[df.RestingBP>(df.RestingBP.mean()+3*df.RestingBP.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 109   39   M           ATA        190          241          0     Normal
# 241   54   M           ASY        200          198          0     Normal
# 365   64   F           ASY        200            0          0     Normal
# 399   61   M           NAP        200            0          1         ST
# 592   61   M           ASY        190          287          1        LVH
# 732   56   F           ASY        200          288          1        LVH
# 759   54   M           ATA        192          283          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease  zscore_cholestrol
# 109    106              N      0.0       Up             0           0.385800
# 241    142              Y      2.0     Flat             1          -0.007310
# 365    140              Y      1.0     Flat             1          -1.817444
# 399     70              N      0.0     Flat             1          -1.817444
# ...

# %%
df2 = df1[df1.RestingBP<(df1.RestingBP.mean()+3*df1.RestingBP.std())]
df2.shape
# Out:
# (908, 13)

# %%
df2[df2.Oldpeak>(df2.Oldpeak.mean()+3*df2.Oldpeak.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 166   50   M           ASY        140          231          0         ST
# 702   59   M            TA        178          270          0        LVH
# 771   55   M           ASY        140          217          0     Normal
# 791   51   M           ASY        140          298          0     Normal
# 850   62   F           ASY        160          164          0        LVH
# 900   58   M           ASY        114          318          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease  zscore_cholestrol
# 166    140              Y      5.0     Flat             1           0.294379
# 702    145              N      4.2     Down             0           0.650921
# 771    111              Y      5.6     Down             1           0.166390
# 791    122              Y      4.2     Flat             1           0.906900
# ...

# %%
df3 = df2[df2.Oldpeak<(df2.Oldpeak.mean()+3*df2.Oldpeak.std())]
df3.shape
# Out:
# (902, 13)

# %%
df4 = pd.get_dummies(df3, drop_first=True)
df4.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0   40        140          289          0    172      0.0             0
# 1   49        160          180          0    156      1.0             1
# 2   37        130          283          0     98      0.0             0
# 3   48        138          214          0    108      1.5             1
# 4   54        150          195          0    122      0.0             0
#
#    zscore_cholestrol  Sex_M  ChestPainType_ATA  ChestPainType_NAP  \
# 0           0.824621      1                  1                  0
# 1          -0.171867      0                  0                  1
# 2           0.769768      1                  1                  0
# 3           0.138964      0                  0                  0
# 4          -0.034736      1                  0                  1
#
#    ChestPainType_TA  RestingECG_Normal  RestingECG_ST  ExerciseAngina_Y  \
# ...

# %%
df4.shape
# Out:
# (902, 17)

# %%
X = df4.drop('HeartDisease', axis=1)
y = df4.HeartDisease

# %%
X.shape, y.shape
# Out:
# ((902, 16), (902,))

# %%
from sklearn.preprocessing import StandardScaler
scalar =  StandardScaler()
X_scaled = scalar.fit_transform(X)
X_scaled
# Out:
# array([[-1.42896269,  0.46089071,  0.85238015, ..., -0.82065181,
#         -1.00221976,  1.13805334],
#        [-0.47545956,  1.5925728 , -0.16132855, ..., -0.82065181,
#          0.99778516, -0.87869344],
#        [-1.74679706, -0.10495034,  0.79657967, ..., -0.82065181,
#         -1.00221976,  1.13805334],
#        ...,
#        [ 0.37209878, -0.10495034, -0.61703246, ...,  1.21854359,
#          0.99778516, -0.87869344],
#        [ 0.37209878, -0.10495034,  0.35947592, ..., -0.82065181,
#          0.99778516, -0.87869344],
#        [-1.64085227,  0.3477225 , -0.20782894, ..., -0.82065181,
#         -1.00221976,  1.13805334]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3)

# %%
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

model_params ={
    'svm' :{
        'model' : SVC(gamma='auto'),
        'params': {
            'kernel':['rbf','linear'],
            'C' : [1,10,20]
        }
    },
    'random_forest':{
        'model': RandomForestClassifier(),
        'params': {
            'n_estimators': [1,5,10]
        }
    },
    'logistic_reg': {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'C': [1,5,10]
        }
    }
}

# %%
from sklearn.model_selection import GridSearchCV

scores = []

for model_name, mp in model_params.items():
    clf = GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model' : model_name,
        'best_params': clf.best_params_,
        'best_score' : clf.best_score_
    })
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#            model  best_score                    best_params
# 0            svm    0.873228  {'C': 20, 'kernel': 'linear'}
# 1  random_forest    0.835133           {'n_estimators': 10}
# 2   logistic_reg    0.870029                       {'C': 1}

# %%
clf.score(X_test, y_test)
# Out:
# 0.8450184501845018

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.score(X_test, y_test)
# Out:
# 0.8450184501845018

# %%
model_svm = SVC()
model_svm.fit(X_train, y_train)
# Out:
# SVC()

# %%
model_svm.score(X_test, y_test)
# Out:
# 0.8487084870848709

# %%
from sklearn.decomposition import PCA
pca = PCA(0.95)

X_pca = pca.fit_transform(X)

# %%
pca.n_components_
# Out:
# 2

# %%
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.2)

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.7569060773480663

# %%
X.shape
# Out:
# (902, 16)

# %%
X_pca.shape
# Out:
# (902, 2)

# %%
df.head()
# Out:
#            model  best_score                    best_params
# 0            svm    0.873228  {'C': 20, 'kernel': 'linear'}
# 1  random_forest    0.835133           {'n_estimators': 10}
# 2   logistic_reg    0.870029                       {'C': 1}

# %%
from sklearn.ensemble import RandomForestClassifier

model_rf = RandomForestClassifier()
model_rf.fit(X_train, y_train)
model_rf.score(X_test, y_test)
# Out:
# 0.7182320441988951

# %%
df5 = df3.copy()

# %%
df5.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease  zscore_cholestrol
# 0              N      0.0       Up             0           0.824621
# 1              N      1.0     Flat             1          -0.171867
# 2              N      0.0       Up             0           0.769768
# 3              Y      1.5     Flat             1           0.138964
# 4              N      0.0       Up             0          -0.034736

# %%
df5.Sex.unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df5.ChestPainType.unique()
# Out:
# array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object)

# %%
df5.RestingECG.unique()
# Out:
# array(['Normal', 'ST', 'LVH'], dtype=object)

# %%
df5.ST_Slope.unique()
# Out:
# array(['Up', 'Flat', 'Down'], dtype=object)

# %%
df5.Sex.replace(
    {
        'M':0,
        'F':1
    }, 
    inplace=True)

df5.ChestPainType.replace(
    {
        'ATA':0,
        'NAP':1,
        'ASY':2,
        'TA':3
    },
    inplace=True)

df5.RestingECG.replace(
    {
        'Normal':0,
        'ST':1,
        'LVH':2
    },
    inplace= True)

df5.ExerciseAngina.replace(
    {
        'N':0,
        'Y':1
    },
    inplace= True)

df5.ST_Slope.replace(
    {
        'Up':0,
        'Flat':1,
        'Down':2
    },
    inplace= True)

df5.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    0              0        140          289          0           0
# 1   49    1              1        160          180          0           0
# 2   37    0              0        130          283          0           1
# 3   48    1              2        138          214          0           0
# 4   54    0              1        150          195          0           0
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease  zscore_cholestrol
# 0    172               0      0.0         0             0           0.824621
# 1    156               0      1.0         1             1          -0.171867
# 2     98               0      0.0         0             0           0.769768
# 3    108               1      1.5         1             1           0.138964
# 4    122               0      0.0         0             0          -0.034736

# %%
X = df5.drop('HeartDisease', axis=1)
y = df5.HeartDisease

# %%
X.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    0              0        140          289          0           0
# 1   49    1              1        160          180          0           0
# 2   37    0              0        130          283          0           1
# 3   48    1              2        138          214          0           0
# 4   54    0              1        150          195          0           0
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  zscore_cholestrol
# 0    172               0      0.0         0           0.824621
# 1    156               0      1.0         1          -0.171867
# 2     98               0      0.0         0           0.769768
# 3    108               1      1.5         1           0.138964
# 4    122               0      0.0         0          -0.034736

# %%
X_scaled_1 = scalar.fit_transform(X)
X_scaled_1
# Out:
# array([[-1.42896269, -0.51485643, -1.6990351 , ..., -0.84676261,
#         -1.0456339 ,  0.85238015],
#        [-0.47545956,  1.94228905, -0.52558207, ...,  0.14079864,
#          0.62072967, -0.16132855],
#        [-1.74679706, -0.51485643, -1.6990351 , ..., -0.84676261,
#         -1.0456339 ,  0.79657967],
#        ...,
#        [ 0.37209878, -0.51485643,  0.64787097, ...,  0.33831089,
#          0.62072967, -0.61703246],
#        [ 0.37209878,  1.94228905, -1.6990351 , ..., -0.84676261,
#          0.62072967,  0.35947592],
#        [-1.64085227, -0.51485643, -0.52558207, ..., -0.84676261,
#         -1.0456339 , -0.20782894]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled_1, y, test_size=0.2, random_state=30)

# %%
X_train.shape, X_test.shape
# Out:
# ((721, 12), (181, 12))

# %%
from sklearn.ensemble import RandomForestClassifier

model_rf = RandomForestClassifier()
model_rf.fit(X_train, y_train)
model_rf.score(X_test, y_test)
# Out:
# 0.8674033149171271

# %%
X.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    0              0        140          289          0           0
# 1   49    1              1        160          180          0           0
# 2   37    0              0        130          283          0           1
# 3   48    1              2        138          214          0           0
# 4   54    0              1        150          195          0           0
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  zscore_cholestrol
# 0    172               0      0.0         0           0.824621
# 1    156               0      1.0         1          -0.171867
# 2     98               0      0.0         0           0.769768
# 3    108               1      1.5         1           0.138964
# 4    122               0      0.0         0          -0.034736

# %%
pca = PCA(0.95)
X_pca_1 = pca.fit_transform(X)
X_pca_1
# Out:
# array([[ 93.82951717, -29.40975303],
#        [-15.58438796, -14.11139273],
#        [ 83.30086253,  38.67556976],
#        ...,
#        [-67.57639341,  17.61571951],
#        [ 40.70726141, -33.39647125],
#        [-19.91407635, -37.29272944]])

# %%
X_train_pca_1, X_test_pca_1, y_train, y_test = train_test_split(X_pca_1, y, test_size=0.2, random_state=30)

# %%
from sklearn.ensemble import RandomForestClassifier

model_rf = RandomForestClassifier()
model_rf.fit(X_train_pca_1, y_train)
model_rf.score(X_test_pca_1, y_test)
# Out:
# 0.7016574585635359
